# %%
#w9a1 
def merge(lst1, lst2):

# %%
#w9a2

# %%
#w9a3

# %%
#w9a9

def median(nums):
    def max_idx(nums):
        max = 1
        for k in nums:
            if k > max:
                max = k
        return max
    
    for k in range(2):
        value_remove = max_idx(nums)
        nums.remove(value_remove)
    return nums[-1]

data_input = list(map(int, input().split()))
print(median(data_input))
# Out:
# 3

# %%
#w9a10 

def findRadiui(houses, heaters):
